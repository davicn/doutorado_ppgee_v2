# %% [markdown]
# # Análise de Paciente PN00

# %%
import pandas as pd
import numpy as np
from scipy.io import loadmat
import os

# %%
PATH = '/media/davi/6A81-05CF/physionet.org/files/siena-scalp-eeg/1.0.0/PN00/'

files = [file for file in os.listdir(PATH) if file.endswith(".mat")]

# %%
file = PATH+files[0]

data = loadmat(file)

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'B', 'P', 'QRS', 'T', 'ecg_signal', 'fs'])

# %%
fs = data['fs'][0,0]

plt.plot(data['QRS'][0])

# %%
import matplotlib.pyplot as plt

plt.plot(data['ecg_signal'][:,:10*fs][0])
